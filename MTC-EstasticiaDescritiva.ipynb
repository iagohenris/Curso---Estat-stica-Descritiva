# %%
dados.shape
# Out:
# (150, 5)

# %%
dados.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
#Cálculo da Média

# %%
med_sl = np.mean(dados['sepal_length'])
med_sl
# Out:
# 5.843333333333335

# %%
med_sl = np.mean(dados['sepal_width'])
med_sl
# Out:
# 3.057333333333334

# %%
med_sl = np.mean(dados['petal_length'])
med_sl
# Out:
# 3.7580000000000027

# %%
med_sl = np.mean(dados['petal_width'])
med_sl
# Out:
# 1.199333333333334

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
np.mean(dados)
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
#Cálculo Mediana

# %%
med_sl = np.median(dados['petal_length'])
med_sl
# Out:
# 4.35

# %%
med_sl = np.median(dados['petal_width'])
med_sl
# Out:
# 1.3

# %%
med_sl = np.median(dados['sepal_length'])
med_sl
# Out:
# 5.8

# %%
med_sl = np.median(dados['sepal_width'])
med_sl
# Out:
# 3.0

# %%
#Cálculo Moda

# %%
moda_sl = dados['sepal_length'].mode()
moda_sl
# Out:
# 0    5.0
# dtype: float64

# %%
moda_sl = dados['sepal_width'].mode()
moda_sl
# Out:
# 0    3.0
# dtype: float64

# %%
moda_sl = dados['petal_length'].mode()
moda_sl
# Out:
# 0    1.4
# 1    1.5
# dtype: float64

# %%
moda_sl = dados['petal_width'].mode()
moda_sl
# Out:
# 0    0.2
# dtype: float64

# %%
#Separatrizes

# %%
P10 = np.quantile(dados['sepal_length'], 0.10)
P10
# Out:
# 4.8

# %%
P50 = np.quantile(dados['sepal_length'], 0.50)
P50
# Out:
# 5.8

# %%
P10 = np.quantile(dados['sepal_width'], 0.10)
P10
# Out:
# 2.5

# %%
Q1 = np.quantile(dados['sepal_length'], 0.25)
Q1
# Out:
# 5.1

# %%
Q3 = np.quantile(dados['sepal_length'], 0.75)
Q3
# Out:
# 6.4

# %%
#Informações Condesadas

# %%
dados.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Visão Espacial das Estatísticas Descritivas

# %%
dados.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = dados['sepal_length']
y = dados['sepal_width']

# %%
plt.scatter(x,y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.plot(np.mean(x), np.mean(y), 'or')

plt.plot(np.median(x), np.median(y), 'oy')

plt.plot(x.mode(), y.mode(), 'og')

# %%
a = dados['petal_length']
b = dados['petal_width']

# %%
plt.scatter(a,b)
plt.xlabel('petal_length')
plt.ylabel('petal_width')

plt.plot(np.mean(a), np.mean(b), 'or')

plt.plot(np.median(a), np.median(b), 'oy')

#plt.plot(a.mode(), b.mode(), 'og')
