# %%
from google.colab import files
import io

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23163094-2c7e-4be2-9fda-69a5acffb519" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23163094-2c7e-4be2-9fda-69a5acffb519">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PETR4.SA.csv to PETR4.SA.csv

# %%
# Ler arquivo e carregar pro colab
df = pd.read_csv(io.BytesIO(uploaded['PETR4.SA.csv']))

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (20, 7)

# %%
df.head(3)
# Out:
#          Date       Open       High    Low      Close  Adj Close    Volume
# 0  2019-04-29  27.549999  27.620001  27.34  27.370001  27.266680  27689800
# 1  2019-04-30  27.520000  27.660000  26.98  27.110001  27.007660  39570700
# 2  2019-05-02  26.799999  26.820000  26.52  26.730000  26.629093  37820300

# %%
df.tail(3)
# Out:
#           Date       Open       High        Low      Close  Adj Close    Volume
# 17  2019-05-23  25.900000  25.920000  25.520000  25.840000  25.840000  49527400
# 18  2019-05-24  26.150000  26.360001  25.930000  26.139999  26.139999  34020100
# 19  2019-05-27  26.299999  26.420000  26.290001  26.379999  26.379999   5958500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       20 non-null     object
#  1   Open       20 non-null     float64
#  2   High       20 non-null     float64
#  3   Low        20 non-null     float64
#  4   Close      20 non-null     float64
#  5   Adj Close  20 non-null     float64
#  6   Volume     20 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#             Open       High        Low      Close  Adj Close        Volume
# count  20.000000  20.000000  20.000000  20.000000  20.000000  2.000000e+01
# mean   26.305000  26.567000  26.016000  26.322500  26.242885  4.267958e+07
# std     0.729329   0.636000   0.731037   0.690986   0.684796  1.468141e+07
# min    24.680000  25.420000  24.469999  24.680000  24.586834  5.958500e+06
# 25%    25.867500  26.182500  25.625000  25.895000  25.830557  3.384908e+07
# 50%    26.304999  26.479999  26.040000  26.364999  26.335000  4.135840e+07
# 75%    26.817500  26.957500  26.445000  26.785000  26.683886  5.025915e+07
# max    27.549999  27.660000  27.340000  27.370001  27.266680  7.178030e+07

# %%
CV = df.std() / df.mean() * 100
CV
# Out:
# Open          2.772588
# High          2.393947
# Low           2.809952
# Close         2.625079
# Adj Close     2.609452
# Volume       34.399153
# dtype: float64

# %%
nome = 'Volume'

df[nome].hist()
plt.xlabel(nome, size=14)
plt.ylabel('Frequência', size=14)

plt.plot(df[nome].median(),0,'*r')
plt.plot(df[nome].mean(),0,'og')
plt.show()

# %%
df.iloc[:, 0:6].boxplot()
plt.show()

# %%
sns.boxplot(data = df.iloc[:, 0:6])
plt.show()

# %%
df.iloc[:, 0:6].plot()
plt.show()
